# %%
import syft as sy

# %%
data_site = sy.orchestra.launch(name='cancer-research-center', reset=True)
# Out:
# CRITICAL:syft.server.server:Hash of the signing key 'd44b5...'
# Using SQLiteDBConfig and sqlite:////private/var/folders/0j/dq0cdfcs1ndfj9qwys4wb6_r0000gn/T/syft/a0cdf795a6bc42e08b33ef0feebb3fcd/db/a0cdf795a6bc42e08b33ef0feebb3fcd_json.db
# SyftInfo: You have launched a development server at http://0.0.0.0:None. It is intended only for local use.

# %%
client = data_site.login(email='info@openmined.org', password='changethis')
# Out:
# Logged into <cancer-research-center: High side Datasite> as <info@openmined.org>
# SyftWarning: You are using a default password. Please change the password using `[your_client].account.set_password([new_password])`.

# %%
from ucimlrepo import fetch_ucirepo

breast_cancer_wisconsin_diagnostic = fetch_ucirepo(id=17)

# %%
X = breast_cancer_wisconsin_diagnostic.data.features
y = breast_cancer_wisconsin_diagnostic.data.targets
metadata = breast_cancer_wisconsin_diagnostic.metadata
variables = breast_cancer_wisconsin_diagnostic.variables

# %%
import numpy as np

# %%
SEED = 12345
np.random.seed(SEED)

X_mock = X.apply(lambda s: s + np.mean(s) + np.random.uniform(size=len(s)))
y_mock = y.sample(frac=1, random_state=SEED).reset_index(drop=True)

# %%
X_mock
# Out:
#        radius1   texture1  perimeter1        area1  smoothness1  compactness1  \
# 0    33.046908  29.731572  215.098990  1656.558336     0.247296      0.895168
# 1    35.013667  37.934637  225.663466  1981.439696     1.118171      0.221639
# 2    34.001211  40.764501  222.546536  1858.657787     0.267806      0.563065
# 3    25.751852  40.469032  170.164562  1041.303267     0.878927      1.124912
# 4    34.985017  34.431523  227.101266  1952.773540     0.633473      1.212773
# ..         ...        ...         ...          ...          ...           ...
# 564  36.012392  42.394059  234.670080  2134.456176     1.060566      1.072092
# 565  35.194097  47.765698  223.892378  1916.344139     1.015388      0.273680
# 566  30.823275  48.181910  200.497542  1513.622039     1.024824      1.038824
# 567  35.610587  48.803529  232.468898  1920.585061     0.302334      0.622115
# 568  22.455309  44.085857  140.132400   836.557507     1.031291      0.184721
#
#      concavity1  concave_points1  symmetry1  fractal_dimension1  ...  \
# 0      1.265891         0.790790   0.764319            0.548207  ...
# 1      0.219281         0.627345   0.962795            1.038450  ...
# 2      1.145187         1.005505   0.669716            0.322992  ...
# 3      0.748009         1.015294   0.634187            0.812617  ...
# 4      1.029953         0.878286   0.560093            0.638018  ...
# ..          ...              ...        ...                 ...  ...
# 564    0.615407         0.836373   1.116416            0.556131  ...
# 565    0.773933         0.755011   0.554835            0.955590  ...
# 566    0.674411         0.878005   1.130023            0.181270  ...
# 567    1.055167         0.472299   0.503158            0.831527  ...
# 568    0.512614         0.349609   0.570456            0.492735  ...
#
#        radius3   texture3  perimeter3        area3  smoothness3  compactness3  \
# 0    42.197438  43.739306  292.853545  2900.213334     1.038016      1.677809
# 1    41.954626  49.526826  266.967840  2837.546722     0.374848      0.552945
# 2    39.921702  51.652774  259.925892  2590.168154     0.880825      1.050142
# 3    31.685386  52.333114  206.770449  1448.756206     0.343623      1.242898
# 4    38.932159  42.409209  259.736854  2455.935309     0.309629      1.358670
# ..         ...        ...         ...          ...          ...           ...
# 564  42.059709  52.721334  274.045318  2908.477278     0.882982      1.366946
# 565  40.660043  64.874331  262.376451  2612.375569     0.493913      0.671399
# 566  35.318908  60.481914  234.164269  2004.666674     1.204058      0.745642
# 567  42.828714  65.483213  292.705146  2702.330428     0.472620      1.301056
# 568  25.799282  56.938525  167.013286  1150.019655     0.468936      0.525658
#
#      concavity3  concave_points3  symmetry3  fractal_dimension3
# 0      1.376853         0.961337   1.523891            0.756000
# 1      1.238547         0.332209   0.719879            0.187481
# 2      1.011544         0.496103   1.242959            1.003488
# 3      1.424467         0.986440   1.341156            0.564193
# 4      0.912052         1.218965   1.223406            0.573670
# ..          ...              ...        ...                 ...
# 564    1.567673         0.792424   1.002978            1.099647
# 565    0.920198         1.159534   0.828664            0.327681
# 566    1.174080         0.966384   0.581423            1.011048
# 567    1.745636         1.195384   1.234789            0.509502
# 568    0.884183         0.958234   1.571069            0.243625
#
# [569 rows x 30 columns]

# %%
y_mock
# Out:
#     Diagnosis
# 0           B
# 1           B
# 2           B
# 3           B
# 4           B
# ..        ...
# 564         B
# 565         M
# 566         B
# 567         B
# 568         B
#
# [569 rows x 1 columns]

# %%
features_asset = sy.Asset(
  name = "Breast Cancer Data: Features",
  data = X,
  mock = X_mock
)

targets_asset = sy.Asset(
  name = "Breast Cancer Data: Targets",
  data = y,
  mock = y_mock
)

# %%
features_asset.data.head(n=10)
# Out:
#    radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 0    17.99     10.38      122.80  1001.0      0.11840       0.27760
# 1    20.57     17.77      132.90  1326.0      0.08474       0.07864
# 2    19.69     21.25      130.00  1203.0      0.10960       0.15990
# 3    11.42     20.38       77.58   386.1      0.14250       0.28390
# 4    20.29     14.34      135.10  1297.0      0.10030       0.13280
# 5    12.45     15.70       82.57   477.1      0.12780       0.17000
# 6    18.25     19.98      119.60  1040.0      0.09463       0.10900
# 7    13.71     20.83       90.20   577.9      0.11890       0.16450
# 8    13.00     21.82       87.50   519.8      0.12730       0.19320
# 9    12.46     24.04       83.97   475.9      0.11860       0.23960
#
#    concavity1  concave_points1  symmetry1  fractal_dimension1  ...  radius3  \
# 0     0.30010          0.14710     0.2419             0.07871  ...    25.38
# 1     0.08690          0.07017     0.1812             0.05667  ...    24.99
# 2     0.19740          0.12790     0.2069             0.05999  ...    23.57
# 3     0.24140          0.10520     0.2597             0.09744  ...    14.91
# 4     0.19800          0.10430     0.1809             0.05883  ...    22.54
# 5     0.15780          0.08089     0.2087             0.07613  ...    15.47
# 6     0.11270          0.07400     0.1794             0.05742  ...    22.88
# 7     0.09366          0.05985     0.2196             0.07451  ...    17.06
# 8     0.18590          0.09353     0.2350             0.07389  ...    15.49
# 9     0.22730          0.08543     0.2030             0.08243  ...    15.09
#
#    texture3  perimeter3   area3  smoothness3  compactness3  concavity3  \
# 0     17.33      184.60  2019.0       0.1622        0.6656      0.7119
# 1     23.41      158.80  1956.0       0.1238        0.1866      0.2416
# 2     25.53      152.50  1709.0       0.1444        0.4245      0.4504
# 3     26.50       98.87   567.7       0.2098        0.8663      0.6869
# 4     16.67      152.20  1575.0       0.1374        0.2050      0.4000
# 5     23.75      103.40   741.6       0.1791        0.5249      0.5355
# 6     27.66      153.20  1606.0       0.1442        0.2576      0.3784
# 7     28.14      110.60   897.0       0.1654        0.3682      0.2678
# 8     30.73      106.20   739.3       0.1703        0.5401      0.5390
# 9     40.68       97.65   711.4       0.1853        1.0580      1.1050
#
#    concave_points3  symmetry3  fractal_dimension3
# 0           0.2654     0.4601             0.11890
# 1           0.1860     0.2750             0.08902
# 2           0.2430     0.3613             0.08758
# 3           0.2575     0.6638             0.17300
# 4           0.1625     0.2364             0.07678
# 5           0.1741     0.3985             0.12440
# 6           0.1932     0.3063             0.08368
# 7           0.1556     0.3196             0.11510
# 8           0.2060     0.4378             0.10720
# 9           0.2210     0.4366             0.20750
#
# [10 rows x 30 columns]

# %%
print(y)
# Out:
#     Diagnosis
# 0           M
# 1           M
# 2           M
# 3           M
# 4           M
# ..        ...
# 564         M
# 565         M
# 566         M
# 567         M
# 568         B
#
# [569 rows x 1 columns]

# %%
y.shape
# Out:
# (569, 1)

# %%
X.shape
# Out:
# (569, 30)
